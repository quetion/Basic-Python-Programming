# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Pandas資料建立
# - `DataFrame`常用資料格式，類似Table格式
# - 變數名稱, index, 變數內容

# %% [markdown]
# #### 最常見用法
# - 利用 `np.random.randn`生成 100*4的矩陣
# - 再轉換成DataFrame的資料型態
# - 設定變數名稱 (A,B,C,D)

# %%
# 利用 np.random.randn生成 100*4的矩陣
# 再轉換成DataFrame的資料型態
# 設定變數名稱 (A,B,C,D)
simulation = pd.DataFrame(np.random.randn(100,4),columns=['A','B','C','D'])
# Out:
#            A         B         C         D
# 0   0.955164  0.569706  1.461796 -1.329101
# 1  -1.432139 -0.372836  1.670907 -1.168997
# 2  -1.786885 -1.494149  0.445907 -1.604200
# 3  -0.581999  1.634963 -0.336149  2.327238
# 4   0.120343 -0.962840  0.669944  1.105383
# 5   1.101188  0.171456 -0.487769  0.132233
# 6   0.953695  0.011830  0.038379  1.068288
# 7  -1.129431 -2.333244  0.882208  0.793748
# 8   0.306325 -0.012917 -0.704695 -0.214665
# 9   1.403254 -1.096972  1.293647  0.864897
# 10 -0.764890  0.357349  0.254232 -0.669242
# 11 -2.397587  0.267823  0.703370  0.877595
# 12  1.112814  1.159591 -0.333293  1.561350
# 13  0.501687  0.685083  1.296942 -0.497188
# 14 -1.107622  0.858550  0.003766 -2.086231
# 15 -0.992862  0.643576  0.306040 -0.424977
# 16  2.321657  0.956331 -0.355404  0.557839
# 17  0.487883  0.448606  0.274305  0.223250
# 18  0.187460 -0.007230  0.614814 -0.160381
# 19  0.586692 -0.521268  1.379530 -1.055951
# 20  0.225137  0.407153 -0.962605 -0.174396
# 21  0.108928  1.567786  0.759234 -0.583037
# 22  0.595359  1.453529  0.142974  0.476527
# 23 -0.175052 -1.118276 -0.505502 -0.559967
# 24  0.346337 -0.325195  0.287501 -1.691607
# 25 -0.048227  0.515442 -0.425232 -1.371773
# 26  0.546633 -0.613487 -0.907953 -0.413725
# 27  1.005403 -0.671474  1.290166  0.534011
# 28 -0.548358  0.994711 -1.777440  0.023908
# 29 -0.719677 -2.949420 -0.106678 -0.713872
# ..       ...       ...       ...       ...
# 70 -1.953354  0.188178  0.161103 -0.987954
# 71  1.443664 -0.173653  0.730580  1.089777
# 72 -0.233826 -1.207127 -0.138156  1.505873
# 73  3.695797  1.053428  0.617865  0.074738
# 74  0.036859 -0.026023  0.016680  0.353263
# 75 -0.355111 -1.725349  0.179334  0.287830
# 76  0.585276  0.548259  0.951215 -0.626197
# 77  0.748103 -0.707048  1.117279 -0.255484
# 78 -1.786583 -0.672688  0.376572 -1.673622
# 79 -1.141856 -0.808067  0.312242 -0.490156
# 80  0.400549  0.618451 -0.160244 -1.820483
# 81  0.814365  0.032985 -0.195946 -0.626828
# 82 -0.183138 -1.024656 -0.241247  0.918484
# 83  1.567317  1.644382 -0.232556  0.291876
# 84 -1.075352  0.591940  0.196213  0.864075
# 85 -1.137188  1.534475 -2.122968 -1.011091
# 86  0.083904  0.847198 -0.466077  0.346213
# 87 -0.200340 -1.314939 -1.091337 -0.200479
# 88 -0.322750 -0.136258 -0.394500 -0.232435
# 89 -1.721480 -0.861949  0.168555 -1.299653
# 90 -0.634022  0.625282 -0.637012 -1.425460
# 91  1.235027  0.400045 -0.284011 -0.788702
# 92  0.484124 -0.457940 -1.052256 -0.115850
# 93 -1.111949  0.373053 -2.153643  1.964323
# 94 -0.896973 -0.092529  0.334969  1.064287
# 95  0.494883 -1.114606  0.410470 -0.854315
# 96  0.734943 -1.096478 -0.951584  1.130343
# 97  1.848947  0.322037 -0.549451  0.751485
# 98  0.271433  2.303680 -1.188278  0.400457
# 99 -0.339172  1.467833 -0.499671  0.589095
#
# [100 rows x 4 columns]

# %% [markdown]
# - `pd.DataFrame({'key':['a','b','a','a','b','c'],'value': range(6)})`
# - 兩個變數，key與value

# %%
left1 = pd.DataFrame({'key':['a','b','a','a','b','c'],
                     'value': range(6)})

# %% [markdown]
# - `pd.DataFrame({'group_val': [3.5,7]},index=['a','b'])`
# - 一個變數: group_val
# - 設定index為 a,b

# %%
right1 = pd.DataFrame({'group_val': [3.5,7]},
                      index=['a','b'])

# %%
left1
# Out:
#   key  value
# 0   a      0
# 1   b      1
# 2   a      2
# 3   a      3
# 4   b      4
# 5   c      5

# %% [markdown]
# ### 生成一個資料庫內有`遺失值`
# - `data.iloc[1,1] = np.nan `選擇特定位置給值(NaN)
# - `.dropna(thresh=2)`丟掉2個以上遺失值的資料

# %%
df = pd.DataFrame(np.random.randn(7,3),columns=['A','B','C'])

# %%
df.iloc[:4,1] = np.nan
df.iloc[:2,2] = np.nan
df
# Out:
#           A         B         C
# 0 -0.253754       NaN       NaN
# 1 -0.119045       NaN       NaN
# 2 -0.786578       NaN -0.611454
# 3 -0.536654       NaN -1.618277
# 4  1.312382  0.863454 -0.280453
# 5  0.052933 -1.050575 -0.120576
# 6 -0.010081 -0.711409  0.468316

# %%
df.dropna(thresh=2)
# Out:
#           A         B         C
# 2 -0.786578       NaN -0.611454
# 3 -0.536654       NaN -1.618277
# 4  1.312382  0.863454 -0.280453
# 5  0.052933 -1.050575 -0.120576
# 6 -0.010081 -0.711409  0.468316

# %% [markdown]
# ### 處理遺失值
# - `data.isnull()`判斷資料中的遺失值: 得到True/False
# - `data.notnull()`判斷資料中**非**遺失值
# - `data.dropna()`回傳非遺失值資料
# - `data[data.notnull()]`意思同上

# %% [markdown]
# ### 資料合併
# - `pd.merge(data1,data2,on='date')`
# - 根據日期(date)合併 (也可選擇同時用兩個變數來合併) `on=['date','XX']`
# - 若不設定，則自行判斷(相同變數名稱)
# - `pd.merge(data1[['date','VIX1'],data2[['date','r1','r2']]]`
# - 只選擇特定幾個變數來合併

# %%
import pandas as pd

# %% [markdown]
# - 匯入資料

# %%
data1 = pd.read_csv('vixts.csv',names=['date','VIX1','VIX2','VIX3','VIX6','VIX9','VIX12'],header = 0)

# %%
data2 = pd.read_csv('straddle_ret.csv', names = ['date','r1','r2','r3','r6','r9','r12','rs1','rs2','rs3','rs6','rs9','rs12'], header = 6)

# %% [markdown]
# - 合併資料範例

# %%
results = pd.merge(data1[['date','VIX1']][1:20],data2[5:10])
results
# Out:
#        date     VIX1      r1     r2     r3     r6     r9    r12    rs1    rs2  \
# 0  19960112  0.01926  -1.134 -1.423 -3.053 -4.441 -1.237 -0.338  0.152  0.274
# 1  19960115  0.02199  -1.035  2.117  3.950  5.082  1.465  0.881  0.141 -0.406
# 2  19960116  0.01891  10.329  0.773  2.182  2.476 -0.704  0.194 -1.552 -0.156
# 3  19960117  0.01908  -0.054  1.091  1.050  0.583 -0.306 -0.460  0.007 -0.206
# 4  19960118  0.01834   0.000 -0.011 -0.150 -0.304 -0.652 -1.144  0.000  0.002
#
#      rs3    rs6    rs9   rs12
# 0  0.711  1.512  0.531  0.172
# 1 -0.898 -1.662 -0.623 -0.447
# 2 -0.535 -0.887  0.307 -0.100
# 3 -0.239 -0.195  0.131  0.235
# 4  0.035  0.103  0.280  0.584

# %% [markdown]
# - 若兩資料沒有相同變數名稱
# - 也可進行合併，需指定變數名稱

# %%
data1 = pd.read_csv('vixts.csv',names=['Date','VIX1','VIX2','VIX3','VIX6','VIX9','VIX12'],header = 0)
data2 = pd.read_csv('straddle_ret.csv', \
                    names = ['date','r1','r2','r3','r6','r9','r12','rs1','rs2','rs3','rs6','rs9','rs12'], header = 6)

# %%
results = pd.merge(data1,data2,left_on='Date',right_on='date')
results.head()
# Out:
#        Date     VIX1     VIX2     VIX3     VIX6     VIX9    VIX12      date  \
# 0  19960105  0.01708  0.01674  0.01661  0.01828  0.02034  0.01993  19960105
# 1  19960108  0.01610  0.01589  0.01582  0.01739  0.01863  0.01955  19960108
# 2  19960109  0.02406  0.01904  0.01675  0.01858  0.01955  0.02088  19960109
# 3  19960110  0.02494  0.02151  0.02006  0.01978  0.02079  0.02184  19960110
# 4  19960111  0.01975  0.01932  0.01912  0.01829  0.01920  0.02071  19960111
#
#        r1     r2     r3     r6     r9    r12    rs1    rs2    rs3    rs6  \
# 0  -4.067  0.827  1.018 -0.307 -0.067  0.855  0.500 -0.145 -0.221  0.101
# 1  -1.795 -0.642 -0.443  0.307  0.234  0.167  0.224  0.116  0.098 -0.101
# 2  34.233  9.657  4.109 -0.396 -0.324  4.148 -4.098 -1.743 -0.916  0.132
# 3   0.968 -2.854 -1.956  0.723 -0.770 -5.758 -0.139  0.597  0.482 -0.246
# 4  -9.191 -6.238 -3.260  1.116 -1.824 -1.151  1.410  1.363  0.842 -0.404
#
#      rs9   rs12
# 0  0.029 -0.428
# 1 -0.101 -0.085
# 2  0.141 -2.104
# 3  0.340  3.095
# 4  0.835  0.594

# %% [markdown]
# ### 主成分分析

# %%
from sklearn.decomposition import PCA

# %%
data_vix = data[['VIX1','VIX2','VIX3','VIX6','VIX9','VIX12']][:]

# %%
pca = PCA(n_components=2)
newData = pca.fit_transform(data_vix)
newData

# %%
data_vix
